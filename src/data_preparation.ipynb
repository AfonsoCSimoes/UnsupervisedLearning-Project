# %% [markdown]
# # Imports & File Reading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "../data/raw/hotel_bookings_course_release_v1.csv"
df = pd.read_csv(file_path)

print(f"Dataset successfuly loaded: Lines: {df.shape[0]} | Columns: {df.shape[1]}")
# Out:
# Dataset successfuly loaded: Lines: 119390 | Columns: 32
